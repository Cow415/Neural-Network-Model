# %% [markdown]
# # Final Project-Building NN From Scratch
# Work from this script, pull basic function and classes from other built script.
# \
# First: Let's import

# %%
# Import libraries and built functions
import helpers
import data_processing
import classes

import numpy as np
